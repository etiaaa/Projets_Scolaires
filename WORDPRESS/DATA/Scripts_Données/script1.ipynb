# %%
#Import des modules nécessaires à savoir requests pour créer,utiliser et excécuter nos requêtes et selenium comme recommander. 

import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
#Création d'une variable "url" qui stock le lien du site à scrapper.

url = 'https://www.zalando.fr/mode-femme/'

# %%
#Création d'une variable "driver" qui permet d'ouvrir le lien du site dans une nouvelle fenêtre.

driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)
# Out:
# C:\Users\Etia\AppData\Local\Temp\ipykernel_11128\226320322.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")

# %%
#Création du tableau où seront stocker les données.

tableau = []

#Création d'une variable "produits" qui stockera tous les éléments des nouveaux vêtements. 

produits = driver.find_elements("xpath",'//*[@id="main-content"]/div/div/div[7]/div/div/div[1]/div')

# %%
#Création d'une boucle qui récupèrera les noms et les produits des vêtements nouveaux. 

i=1 #Initialisation d'une variable i qui sera incrémenter à chaque tour de la boucle afin de modifier les liens et accéder aux différents produits.
for j in range(90): #limitation des produits à afficher 
    try:
        nom = driver.find_element("xpath",f'//*[@id="main-content"]/div/div/div[7]/div/div/div[1]/div[2]/div[{i}]/div/article/div[4]/a/header/div/h3[2]').text
        prix = driver.find_element("xpath",f'//*[@id="main-content"]/div/div/div[7]/div/div/div[1]/div[2]/div[{i}]/div/article/div[4]/a/header/section/p[1]/span').text
        print(nom)
        print(prix)
        tableau.append([nom, prix])
    except:
        print("Donnée Manquante")
    i+=1
# Out:
# Pullover - navy
# 29,95 €
# PARACHUTE POPELIN - Pantalon de survêtement - black
# 19,99 €
# Veste en similicuir - black
# 29,99 €
# MIT HOHEM BUND - Jeans Skinny - blue
# 19,99 €
# Donnée Manquante
# Jeans Skinny - mottled light blue
# 19,99 €
# Donnée Manquante
# IGGY - Combinaison - black denim
# 59,99 €
# MIT ZIERNAHT VORNE - Pantalon classique - black
# 25,99 €
# MOM - Jean droit - black
# 19,99 €
# Jean slim - blue denim
# 19,99 €
# Donnée Manquante
# PARACHUTE POPELIN - Pantalon de survêtement - offwhite
# à partir de
# Donnée Manquante
# ONLBANDIT BIKER - Veste en similicuir - black
# 31,69 €
# MOM - Jean droit - dark blue denim
# 19,99 €
# Pantalon cargo - black
# 29,99 €
# Jupe trapèze - black
# 15,99 €
# LONG FLOWING RUSTIC - Pantalon classique - off white
# 19,99 €
# THE PERFECT TEE - T-shirt imprimé - white
# 23,95 €
# MIA2 - Jupe trapèze - nero
# 39,99 €
# Donnée Manquante
# Donnée Manquante
# MOM - Jean droit - stone blue denim
# 19,99 €
# Donnée Manquante
# ONLNICOLE LIFE MIX - T-shirt imprimé - black
# 16,99 €
# VMKERRIULTRA - Veste en similicuir - black
# 41,99 €
# Donnée Manquante
# 501® CROP - Jean droit - cabo fade
# à partir de
# T-shirt basique - white
# 9,99 €
# ONLTAHOE HOOD OTW NOOS - Veste d'hiver - black
# 35,19 €
# PERFECT TEE - T-shirt basique - white
# 19,95 €
# INTENSE POWER TRIANGLE BRAS - Haut de bikini - black
# à partir de
# OVERSIZE SHORT SLEEVE - T-shirt imprimé - dark grey
# 7,99 €
# Donnée Manquante
# Donnée Manquante
# LE VRAI CLAUDE 3.0 - Veste imperméable - depth blue
# à partir de
# LOOP - Pantalon classique - black
# 25,99 €
# MIT SEHR HOHEM BUND - Jeans Skinny - light blue
# 19,99 €
# Donnée Manquante
# LANGER IM COMFORT-FIT - Jupe en jean - mottled royal blue
# 29,99 €
# Gilet - weiß
# 24,99 €
# WITH POCKETS - Veste légère - mottled black
# 25,99 €
# Trench - ochre
# à partir de
# ONLWAUW LIFE MID - Jeans Skinny - medium blue denim
# à partir de
# ONLELLY 3/4 LIFE TLR NOOS - Manteau court - simply green
# 38,39 €
# STRAIGHT FIT - Pantalon cargo - dark grey
# 29,99 €
# MOM - Short en jean - light blue
# 19,99 €
# ONLPOPTRASH LIFE EASY COL PNT NOOS - Pantalon classique - black
# 27,99 €
# Donnée Manquante
# DB ESNTL CT - Trench - sand
# à partir de
# Donnée Manquante
# MIT HOHEM BUND - Jeans Skinny - black
# 19,99 €
# MOM - Jean boyfriend - light blue denim
# 19,99 €
# BASIC - Veste légère - sand
# 39,99 €
# MIT SUPERHOHEM BUND - Pantalon classique - black
# 19,99 €
# FORMAL - Pantalon classique - black
# 25,99 €
# Combinaison - dark blue denim
# 45,99 €
# Legging - black
# 16,95 €
# ONLMOSTER SS O-NECK NOOS JRS - T-shirt basique - etherea
# 16,99 €
# MIT SUPERHOHEM - Jeans Skinny - black
# 19,99 €
# ONLMOSTER SS O-NECK NOOS JRS - T-shirt basique - white
# 12,79 €
# Veste en similicuir - light brown
# 49,99 €
# NEW BRIGHTON OTW NOOS - Manteau court - black
# 39,99 €
# MOM - Jean droit - dark blue
# 19,99 €
# BANDEAU - Débardeur - black
# 7,99 €
# JUPE STELLA - Jupe trapèze - black
# 52,40 €
# Donnée Manquante
# ASTRID BOLERO - Gilet - chalk
# 29,95 €
# DAD FIT - Pantalon classique - dark grey
# 29,99 €
# ONLBLUSH LIFE MID - Jeans Skinny - light medium blue denim
# 33,99 €
# MOM - Jean boyfriend - black
# 19,99 €
# HIGH WAISTED - Jeans Skinny - dark blue denim
# 19,99 €
# DAYS CIGERET PANTS - Chino - camel
# 39,95 €
# WITH SIDE ZIP - Veste en similicuir - black
# 29,99 €
# WIDE LEG TAILORED - Pantalon classique - black
# 25,99 €
# ONLSEDONA OTW NOOS - Manteau court - black
# à partir de
# MOM - Jean droit - grey
# 19,99 €
# Débardeur - black
# 9,99 €
# REGULAR­FIT TAILORED - FEMININE-CUT DOUBLE-BREASTED - Manteau court - black
# 35,99 €
# Donnée Manquante
# VMMAYA - Pantalon classique - black
# 24,59 €
# ONLMOSTER SS O-NECK NOOS JRS - T-shirt basique - henna
# 16,99 €
# PUSH UP - Jean slim - black
# 22,99 €
# Short - black
# 9,99 €
# MOM - Jean droit - mottled dark blue
# 19,99 €
# STRIPED CROPPED - T-shirt imprimé - red
# 7,99 €
# MOM - Jean boyfriend - dark blue
# 19,99 €
# Pantalon de survêtement - grey
# 12,99 €
# T-shirt imprimé - dark blue
# 5,99 €

# %%
#Affichage du tableau avec toutes les données stocker.   
print(tableau)
# Out:
# [['Pullover - navy', '29,95 €'], ['PARACHUTE POPELIN - Pantalon de survêtement - black', '19,99 €'], ['Veste en similicuir - black', '29,99 €'], ['MIT HOHEM BUND - Jeans Skinny - blue', '19,99 €'], ['Jeans Skinny - mottled light blue', '19,99 €'], ['IGGY - Combinaison - black denim', '59,99 €'], ['MIT ZIERNAHT VORNE - Pantalon classique - black', '25,99 €'], ['MOM - Jean droit - black', '19,99 €'], ['Jean slim - blue denim', '19,99 €'], ['PARACHUTE POPELIN - Pantalon de survêtement - offwhite', 'à partir de'], ['ONLBANDIT BIKER - Veste en similicuir - black', '31,69 €'], ['MOM - Jean droit - dark blue denim', '19,99 €'], ['Pantalon cargo - black', '29,99 €'], ['Jupe trapèze - black', '15,99 €'], ['LONG FLOWING RUSTIC - Pantalon classique - off white', '19,99 €'], ['THE PERFECT TEE - T-shirt imprimé - white', '23,95 €'], ['MIA2 - Jupe trapèze - nero', '39,99